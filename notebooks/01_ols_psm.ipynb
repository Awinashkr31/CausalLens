# %% [markdown]
# # 01: OLS and Propensity Score Matching (PSM)

# %%
import pandas as pd
import sys
sys.path.append("../")
from src.estimators import ols_adjustment, estimate_psm
from src.diagnostics import check_balance, plot_propensity_overlap

# %%
df = pd.read_csv("../data/processed/simulated_sample.csv")
outcome = "outcome"
treatment = "treatment"
covariates = ["age", "income", "prior_outcome"]

# %%
balance = check_balance(df, treatment, covariates)
balance

# %%
plot_propensity_overlap(df, treatment, covariates)

# %%
ols_model = ols_adjustment(df, outcome, treatment, covariates)
print(ols_model.summary())

# %%
psm_ate = estimate_psm(df, outcome, treatment, covariates)
print("PSM ATE:", psm_ate)

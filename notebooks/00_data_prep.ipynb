# %% [markdown]
# # 00: Data Preparation & Simulation
# In this notebook we generate and prepare causal data.

# %%
import pandas as pd
import sys
sys.path.append("../")
from src.data_io import generate_simulated_data, save_data

# %%
df = generate_simulated_data(2500)
df.head()

# %%
save_data(df, "../data/processed/simulated_sample.csv")
print("Data saved!")
